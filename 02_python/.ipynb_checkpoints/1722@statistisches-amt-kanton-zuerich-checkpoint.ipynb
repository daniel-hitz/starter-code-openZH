# %% [markdown]
# ## Open Government Data, provided by **Canton Zurich**
# *Autogenerated Python starter code for data set with identifier* **1722@statistisches-amt-kanton-zuerich**

# %% [markdown]
# ## Dataset
# # **Anteil Gemeinnützige Wohnungen in Gemeinden des Kantons Zürich [%]**

# %% [markdown]
# ## Description
#
# Anteil Wohnungen (am Gesamtwohnungsbestand) in Gebäuden, die dem gemeinnützigen Sektor zuzuordnen sind. Das Bundesamt für Wohnungswesen (BWO), das die Daten erhebt, schätzt, dass rund 90 Prozent aller sich im Besitz des gemeinnützigen Sektors befindlichen Wohnungen erfasst werden. Nicht erfasst werden Wohnungen in Gebäuden in direktem kommunalen Besitz (in der Stadt Zürich zum Beispiel die städtischen Wohnungen). Es ist nicht zulässig, die jährliche Veränderung des Indikators als reale Zu- bzw. Abnahme des gemeinnützigen Wohnungsbestandes zu interpretieren, weil die Datengrundlage nur alle fünf Jahre systematisch aktualisiert wird. Insbesondere grosse Veränderungen sind in der Regel der nachträglichen Erfassung von Gebäuden geschuldet.

# %% [markdown]
# ## Data set links
#
# [Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/opendata.html#/datasets/1722@statistisches-amt-kanton-zuerich)

# %% [markdown]
# ## Metadata
# - **Issued** `2022-09-19T16:51:19`
# - **Modified** `2023-04-14T08:55:52`
# - **Startdate** `2016-12-31`
# - **Enddate** `2021-12-31`
# - **Theme** `['Bau- und Wohnungswesen', 'Soziale Sicherheit']`
# - **Keyword** `['bezirke', 'gemeinden', 'kanton_zuerich', 'mietwohnungen', 'wohnungen', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3220
# Title                    : Anteil Gemeinnützige Wohnungen [%]
# Description              : None
# Issued                   : 2022-09-19T16:51:19
# Modified                 : 2023-04-14T08:55:52
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_841.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 1,148 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           1148 non-null   int64
#  1   GEBIET_NAME      1148 non-null   object
#  2   THEMA_NAME       1148 non-null   object
#  3   SET_NAME         1148 non-null   object
#  4   SUBSET_NAME      1148 non-null   object
#  5   INDIKATOR_ID     1148 non-null   int64
#  6   INDIKATOR_NAME   1148 non-null   object
#  7   INDIKATOR_JAHR   1148 non-null   int64
#  8   INDIKATOR_VALUE  1148 non-null   float64
#  9   EINHEIT_KURZ     1148 non-null   object
#  10  EINHEIT_LANG     1148 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 743.5 KB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# 0       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 1       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 2       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 3       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# 4       1  Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
#
#        SUBSET_NAME  INDIKATOR_ID                      INDIKATOR_NAME  \
# 0  Wohnungsbestand           841  Anteil Gemeinnützige Wohnungen [%]
# 1  Wohnungsbestand           841  Anteil Gemeinnützige Wohnungen [%]
# 2  Wohnungsbestand           841  Anteil Gemeinnützige Wohnungen [%]
# 3  Wohnungsbestand           841  Anteil Gemeinnützige Wohnungen [%]
# 4  Wohnungsbestand           841  Anteil Gemeinnützige Wohnungen [%]
#
#    INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0            2016              0.0            %      Prozent
# 1            2017              0.0            %      Prozent
# 2            2018              0.0            %      Prozent
# 3            2019              0.0            %      Prozent
# 4            2020              0.0            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                 707  \
# BFS_NR                                          181
# GEBIET_NAME                                    Wila
# THEMA_NAME                       Bau und Immobilien
# SET_NAME                Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                         Wohnungsbestand
# INDIKATOR_ID                                    841
# INDIKATOR_NAME   Anteil Gemeinnützige Wohnungen [%]
# INDIKATOR_JAHR                                 2017
# INDIKATOR_VALUE                                 0.0
# EINHEIT_KURZ                                      %
# EINHEIT_LANG                                Prozent
#
#                                                 455  \
# BFS_NR                                           98
# GEBIET_NAME                             Schleinikon
# THEMA_NAME                       Bau und Immobilien
# SET_NAME                Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                         Wohnungsbestand
# INDIKATOR_ID                                    841
# INDIKATOR_NAME   Anteil Gemeinnützige Wohnungen [%]
# INDIKATOR_JAHR                                 2018
# INDIKATOR_VALUE                                 0.0
# EINHEIT_KURZ                                      %
# EINHEIT_LANG                                Prozent
#
#                                                 897
# BFS_NR                                          243
# GEBIET_NAME                                Dietikon
# THEMA_NAME                       Bau und Immobilien
# SET_NAME                Wohnungen, Wohnbautätigkeit
# SUBSET_NAME                         Wohnungsbestand
# INDIKATOR_ID                                    841
# INDIKATOR_NAME   Anteil Gemeinnützige Wohnungen [%]
# INDIKATOR_JAHR                                 2017
# INDIKATOR_VALUE                                 5.9
# EINHEIT_KURZ                                      %
# EINHEIT_LANG                                Prozent

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")
# Out:
#         GEBIET_NAME          THEMA_NAME                     SET_NAME  \
# count          1148                1148                         1148
# unique          197                   1                            1
# top     Aeugst a.A.  Bau und Immobilien  Wohnungen, Wohnbautätigkeit
# freq              6                1148                         1148
#
#             SUBSET_NAME                      INDIKATOR_NAME EINHEIT_KURZ  \
# count              1148                                1148         1148
# unique                1                                   1            1
# top     Wohnungsbestand  Anteil Gemeinnützige Wohnungen [%]            %
# freq               1148                                1148         1148
#
#        EINHEIT_LANG
# count          1148
# unique            1
# top         Prozent
# freq           1148

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 1,148.00      1,148.00        1,148.00         1,148.00
# mean    109.96        841.00        2,018.46             3.28
# std      88.42          0.00            1.71             3.96
# min       0.00        841.00        2,016.00             0.00
# 25%      30.00        841.00        2,017.00             0.00
# 50%      94.00        841.00        2,018.00             2.20
# 75%     182.00        841.00        2,020.00             5.20
# max     298.00        841.00        2,021.00            20.30

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 3
#       1 # check missing values with missingno
#       2 # https://github.com/ResidentMario/missingno
# ----> 3 import missingno as msno
#       4 msno.matrix(df, labels=True, sort='descending')
#
# ModuleNotFoundError: No module named 'missingno'

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Questions about the data?** Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch
